# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# # 1.View and call dataset to environment ?

# %%
df=pd.read_csv("C:/Users/admin/Downloads/auto_data.csv")

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# # 2.Find info , top 5 records , bottom 5 records ?

# %%
top5=df.head(5)
print(top5)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                       name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
top5=df.tail(5)
print(top5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model_year  origin             name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %% [markdown]
# # 3.Represent Corelation between variables ?

# %%
corelation_variable = df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corelation_variable)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7664\2214835141.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corelation_variable = df.corr()

# %% [markdown]
# # plot different kinds of graphs for mean value represetation ? (use required headers) ?

# %%
mean_values= df.mean()
plt.figure(figsize=(10,8))
sns.boxplot(x="cylinders",y="weight",data=df)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7664\2587324262.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean_values= df.mean()

# %%
mean_values= df.mean()
plt.figure(figsize=(10,8))
sns.violinplot(x="cylinders",y="weight",data=df)
plt.show()
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_7664\130743264.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean_values= df.mean()

# %% [markdown]
# # Draw the pair plot using sns for mpg, weight,orign and with hue origin, set the size to 4 ?

# %%
sns.pairplot(df[["mpg","weight","origin"]],hue="origin",height=4)
plt.show()

# %% [markdown]
# # Identify how many types of  cylinder vehicles you have ? (GroupBY)

# %%
cylinders=df.groupby('cylinders').value_counts()
print(cylinders)
# Out:
# cylinders  mpg   displacement  horsepower  weight  acceleration  model_year  origin  name
# 3          18.0  70.0          90          2124    13.5          73          3       maxda rx3                       1
#            19.0  70.0          97          2330    13.5          72          3       mazda rx2 coupe                 1
#            23.7  70.0          100         2420    12.5          80          3       mazda rx-7 gs                   1
#            21.5  80.0          110         2720    13.5          77          3       mazda rx-4                      1
# 4          46.6  86.0          65          2110    17.9          80          3       mazda glc                       1
#                                                                                                                     ..
# 8          14.0  302.0         140         4638    16.0          74          1       ford gran torino (sw)           1
# ...

# %% [markdown]
# # how many vehicles in every  model_year ?

# %%
vehicle_counts_by_year = df.groupby('model_year').size().reset_index()

print(vehicle_counts_by_year)
# Out:
#     model_year   0
# 0           70  29
# 1           71  28
# 2           72  28
# 3           73  40
# 4           74  27
# 5           75  30
# 6           76  34
# 7           77  28
# 8           78  36
# 9           79  29
# 10          80  29
# 11          81  29
# 12          82  31
