# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:/Users/admin/Downloads/9.ibm.csv")

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# # •	To find the employee who are the highest salary in monthly income

# %%
sal =df['MonthlyIncome'],
higestsal =max('MonthlyIncome')
print(higestsal)
# Out:
# 19545 the higest monthly income employee

# %%
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# # here i showed which age grup have higest income

# %%
 
sns.scatterplot(x='Age',y='MonthlyIncome',data=df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 2
#       1 sns.scatterplot(x='Age',y='MonthlyIncome',data=df)
# ----> 2 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_api\__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %% [markdown]
# # •	To find Employees, how many employees are worked as “Research Scientist” and “Sales Executive”.

# %%
job_roles_to_count = ["Research Scientist", "Sales Executive"]

filtered_df = df[df['JobRole'].isin(job_roles_to_count)]

print(f"Number of Employees with 'Research Scientist' and 'Sales Executive' Job Roles: {employee_count_with_both_roles}")
# Out:
# Number of Employees with 'Research Scientist' and 'Sales Executive' Job Roles: 40

# %% [markdown]
# # •	To find the employee marital status as ascending to descending order by using dataset

# %%
ascending =df.sort_values(by='MaritalStatus',ascending = True)
print(ascending)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 35   43        No      Travel_Rarely       1273  Research & Development
# 52   44        No      Travel_Rarely       1488                   Sales
# 79   46        No      Travel_Rarely        945         Human Resources
# 20   24        No         Non-Travel        673  Research & Development
# 17   22        No         Non-Travel       1123  Research & Development
# ..  ...       ...                ...        ...                     ...
# 55   33        No  Travel_Frequently        515  Research & Development
# 61   38        No  Travel_Frequently        653  Research & Development
# 63   59        No      Travel_Rarely       1435                   Sales
# 30   33        No      Travel_Rarely        924  Research & Development
# 98   58        No      Travel_Rarely        682                   Sales
#
#     DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# ...

# %% [markdown]
# # •	To find employees, who are in the medical field ?

# %%
field=df[df["EducationField"]== "Medical"]
print(field)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 4    27        No      Travel_Rarely        591  Research & Development
# 6    59        No      Travel_Rarely       1324  Research & Development
# 9    36        No      Travel_Rarely       1299  Research & Development
# 10   35        No      Travel_Rarely        809  Research & Development
# 13   34        No      Travel_Rarely       1346  Research & Development
# 17   22        No         Non-Travel       1123  Research & Development
# 24   34       Yes      Travel_Rarely        699  Research & Development
# 28   44        No      Travel_Rarely        477  Research & Development
# 30   33        No      Travel_Rarely        924  Research & Development
# 32   30        No      Travel_Rarely        125  Research & Development
# 34   24       Yes      Travel_Rarely        813  Research & Development
# 35   43        No      Travel_Rarely       1273  Research & Development
# ...

# %% [markdown]
# # •	In employees how many of them are satisfaction with the environment.

# %%
satisfaction_threshold = 3
satisfaction=(df["EnvironmentSatisfaction"] == satisfaction_threshold).sum()
print(satisfaction)
# Out:
# 28

# %% [markdown]
# # •	Find out the list of employee whose income is more than the average income

# %%
average=df["MonthlyIncome"].mean()
high_income = df[df['MonthlyIncome'] >= average]
print(high_income)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 8    38        No  Travel_Frequently        216  Research & Development
# 15   29        No      Travel_Rarely       1389  Research & Development
# 18   53        No      Travel_Rarely       1219                   Sales
# 22   34        No      Travel_Rarely        419  Research & Development
# 25   53        No      Travel_Rarely       1282  Research & Development
# 27   42        No      Travel_Rarely        691                   Sales
# 28   44        No      Travel_Rarely        477  Research & Development
# 29   46        No      Travel_Rarely        705                   Sales
# 31   44        No      Travel_Rarely       1459  Research & Development
# 43   27        No  Travel_Frequently        994                   Sales
# 45   41       Yes      Travel_Rarely       1360  Research & Development
# 53   35        No         Non-Travel       1097  Research & Development
# ...

# %% [markdown]
# # •	To find the AGEof employees more than 35 yea rs.

# %%
age=df[df["Age"]>35]
print(age)
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 6    59        No      Travel_Rarely       1324  Research & Development
# 8    38        No  Travel_Frequently        216  Research & Development
# 9    36        No      Travel_Rarely       1299  Research & Development
# 18   53        No      Travel_Rarely       1219                   Sales
# 19   38        No      Travel_Rarely        371  Research & Development
# 21   36       Yes      Travel_Rarely       1218                   Sales
# 25   53        No      Travel_Rarely       1282  Research & Development
# 27   42        No      Travel_Rarely        691                   Sales
# 28   44        No      Travel_Rarely        477  Research & Development
# ...

# %% [markdown]
# # •	In Business travel, how many number of employees are travel frequen

# %%
bussines_travel=df[df["BusinessTravel"]=="Travel_Frequently"]
num_travelers=len(bussines_travel)
print(num_travelers)
# Out:
# 17

# %% [markdown]
# # •	Choose an attribute and generate a boxplot by using dataset i choose gender and age

# %%
sns.boxplot(x="Gender",y="Age",data=df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[155], line 2
#       1 sns.boxplot(x="Gender",y="Age",data=df)
# ----> 2 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_api\__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'show'

# %% [markdown]
# # •	To find the employee ,how many of them leaving the company.

# %%
employees_leaving =len (df[df['Attrition'] == 'Yes'])


print(f"Number of Employees Leaving the Company: {employees_leaving}")
# Out:
# Number of Employees Leaving the Company: 15
